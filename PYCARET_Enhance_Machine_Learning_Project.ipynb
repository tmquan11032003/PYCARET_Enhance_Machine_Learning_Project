# %% [markdown]
# <a href="https://colab.research.google.com/github/tmquan11032003/PYCARET_Enhance_Machine_Learning_Project/blob/main/PYCARET_Enhance_Machine_Learning_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pycaret
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 484.7/484.7 kB 4.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.9/81.9 kB 5.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 11.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 39.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.4/73.4 kB 8.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 36.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.5/160.5 kB 12.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 9.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 12.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 29.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 3.1 MB/s eta 0:00:00
# ...

# %%
from pycaret.classification import *
import pandas as pd
import numpy as np
import os

# %%
os.getcwd()
# Out:
# '/content'

# %%
os.chdir("/content/drive/MyDrive/Colab Tự Học /Data Analyst - PyCaret to Enhance Your Machine Learning")

# %%
print ("Updated directory:" , os.getcwd())
# Out:
# Updated directory: /content/drive/MyDrive/Colab Tự Học /Data Analyst - PyCaret to Enhance Your Machine Learning

# %%
pwd = os.getcwd()
test_filepath = os.path.join(pwd,"test.csv")
train_filepath = os.path.join(pwd,"train.csv")
gender_filepath = os.path.join(pwd,"gender_submission.csv")
pwd
# Out:
# '/content/drive/MyDrive/Colab Tự Học /Data Analyst - PyCaret to Enhance Your Machine Learning'

# %%
test_import = pd.read_csv(test_filepath)
train_import = pd.read_csv(train_filepath)
gender_import = pd.read_csv(gender_filepath)

# %%
test_import
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
 clf1 = setup(data=train_import,
              target="Survived",
              numeric_imputation="mean",
              categorical_features=['Sex', 'Embarked'],
              ignore_features=["Name", "Ticket", "Cabin"],
              remove_outliers = True,
              verbose = True)
# Out:
# <style type="text/css">
# #T_008e7_row12_col1, #T_008e7_row18_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_008e7" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_008e7_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_008e7_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_008e7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_008e7_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_008e7_row0_col1" class="data row0 col1" >2919</td>
#     </tr>
#     <tr>
#       <th id="T_008e7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_008e7_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_008e7_row1_col1" class="data row1 col1" >Survived</td>
#     </tr>
#     <tr>
# ...

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_1d044 th {
#   text-align: left;
# }
# ...

# %%
lgbm = create_model('lightgbm')
# Out:
# <style type="text/css">
# #T_21be9_row10_col0, #T_21be9_row10_col1, #T_21be9_row10_col2, #T_21be9_row10_col3, #T_21be9_row10_col4, #T_21be9_row10_col5, #T_21be9_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_21be9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_21be9_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_21be9_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_21be9_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_21be9_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_21be9_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_21be9_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_21be9_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
turn_lgbm = tune_model(lgbm)
# Out:
# <style type="text/css">
# #T_0bce0_row10_col0, #T_0bce0_row10_col1, #T_0bce0_row10_col2, #T_0bce0_row10_col3, #T_0bce0_row10_col4, #T_0bce0_row10_col5, #T_0bce0_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_0bce0" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0bce0_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_0bce0_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_0bce0_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_0bce0_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_0bce0_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_0bce0_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_0bce0_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
plot_model(estimator=turn_lgbm, plot='learning')

# %%
plot_model(estimator=turn_lgbm, plot='auc')

# %%
plot_model(estimator=turn_lgbm, plot='confusion_matrix')

# %%
plot_model(estimator=turn_lgbm, plot='feature')

# %%
evaluate_model(turn_lgbm)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
predict_model(turn_lgbm,data=test_import)
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [LightGBM] [Warning] bagging_fraction is set=0.6, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [LightGBM] [Warning] bagging_fraction is set=0.6, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# ...
